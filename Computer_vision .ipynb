# %%
import cv2

# %%
cv2.__version__

# %%
img=cv2.imread('/content/akracing.jpg')

# %%
img5=cv2.imread('/content/akracing.jpg',0)

# %%
img

# %%
# from google.colab.patches import cv2_imshow
cv2_imshow(img)

# %%
cv2.imwrite('BW_ak.jpg',img5)

# %%
img.shape

# %%
img.size

# %%
type(img)

# %%
img1=img[50:1500,150:1706]
cv2_imshow(img1)

# %%
img2=cv2.rotate(img,cv2.ROTATE_180)
cv2_imshow(img2)

# %%
img3=cv2.flip(img,1)
cv2_imshow(img3)

# %%
img4=cv2.resize(img,(2000,1000))
cv2_imshow(img4)

# %%
img5=cv2.blur(img,(1,20))
cv2_imshow(img5)
